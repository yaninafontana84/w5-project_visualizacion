# %%
# %pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# librerias a importar

import pandas as pd
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
video_games_sales_ori = pd.read_csv('../data/video_games_sales.csv', encoding='latin1') #leo el archivo "INE"

video_games_sales = video_games_sales_ori.copy() #hago una copia

video_games_sales.head() #miro qué pinta tiene para empezar a limpiar
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
video_games_sales.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
columnas_a_eliminar = ['Global_Sales', 'Critic_Score',
       'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating']

video_games_sales = video_games_sales.drop(columnas_a_eliminar, axis=1)

# %%
video_games_sales
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
video_games_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 1.1+ MB

# %%
unique_count = video_games_sales['Platform'].nunique()
unique_count
# Out:
# 31

# %%
unique_platform = video_games_sales['Platform'].unique()
unique_platform
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
platform_mapping = {
    'Wii': 'Nintendo Wii',
    'NES' : 'NES (Nintendo Entertainment System)', 
    'GB' : 'Nintendo Game Boy', 
    'DS':'Nintendo Dual Screen', 
    'X360': 'Xbox360',
    'PS3': 'PlayStation3', 
    'PS2': 'PlayStation2', 
    'SNES': 'Super Nintendo Entertainment System', 
    'GBA' : 'Game Boy Advance',
    'PS4': 'PlayStation4', 
    '3DS': 'Nintendo 3DS', 
    'N64': 'Nintendo 64', 
    'PS': 'PlayStation', 
    'XB': 'Xbox', 
    '2600': 'Atari 2600', 
    'PSP': 'PlayStation Portable', 
    'XOne': 'Xbox One',
    'WiiU' : 'Nintendo WiiU', 
    'GC' : 'Nintendo GameCube', 
    'GEN': 'Sega Genesis', 
    'DC': 'Sega Dreamcast', 
    'PSV': 'PlayStation Vita', 
    'SAT': 'Sega Saturn', 
    'SCD': 'Sega CD', 
    'WS': 'WonderSwan', 
    'NG': 'Neo Geo', 
    'TG16': 'TurboGrafx-16', 
    'GG': 'Game Gear', 
    'PCFX': 'NEC PC-FX'
}

video_games_sales['Platform'] = video_games_sales['Platform'].replace(platform_mapping)

# %%
unique_platform = video_games_sales['Platform'].unique()
print(unique_platform)
# Out:
# ['Nintendo Wii' 'NES (Nintendo Entertainment System)' 'Nintendo Game Boy'
#  'Nintendo Dual Screen' 'Xbox360' 'PlayStation3' 'PlayStation2'
#  'Super Nintendo Entertainment System' 'Game Boy Advance' 'PlayStation4'
#  'Nintendo 3DS' 'Nintendo 64' 'PlayStation' 'Xbox' 'PC' 'Atari 2600'
#  'PlayStation Portable' 'Xbox One' 'Nintendo WiiU' 'Nintendo GameCube'
#  'Sega Genesis' 'Sega Dreamcast' 'PlayStation Vita' 'Sega Saturn'
#  'Sega CD' 'WonderSwan' 'Neo Geo' 'TurboGrafx-16' '3DO' 'Game Gear'
#  'NEC PC-FX']

# %%
unique_count_g = video_games_sales['Genre'].nunique()
unique_count_g
# Out:
# 12

# %%
unique_genre = video_games_sales['Genre'].unique()
unique_genre
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
column_mapping = {
    'Name': 'Nombre',
    'Platform':'Plataforma',
    'Year_of_Release': 'Año',
    'Genre': 'Género',
    'Publisher': 'Compañía',
    'NA_Sales': 'USA',
    'EU_Sales': 'Europa',
    'JP_Sales': 'Japón',
    'Other_Sales': 'Otros'
}

video_games_sales = video_games_sales.rename(columns=column_mapping)

# %%
unique_count_name = video_games_sales['Nombre'].nunique()
unique_count_name
# Out:
# 11562

# %%
video_games_sales_cleaned = video_games_sales.dropna()

# %%
video_games_sales_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16416 entries, 0 to 16718
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nombre      16416 non-null  object
#  1   Plataforma  16416 non-null  object
#  2   Año         16416 non-null  float64
#  3   Género      16416 non-null  object
#  4   Compañía    16416 non-null  object
#  5   USA         16416 non-null  float64
#  6   Europa      16416 non-null  float64
#  7   Japón       16416 non-null  float64
#  8   Otros       16416 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 1.3+ MB

# %%
video_games_sales_cleaned
# Out:
#                               Nombre                           Plataforma  \
# 0                         Wii Sports                         Nintendo Wii
# 1                  Super Mario Bros.  NES (Nintendo Entertainment System)
# 2                     Mario Kart Wii                         Nintendo Wii
# 3                  Wii Sports Resort                         Nintendo Wii
# 4           Pokemon Red/Pokemon Blue                    Nintendo Game Boy
# ...                              ...                                  ...
# 16714  Samurai Warriors: Sanada Maru                         PlayStation3
# 16715               LMA Manager 2007                              Xbox360
# 16716        Haitaka no Psychedelica                     PlayStation Vita
# 16717               Spirits & Spells                     Game Boy Advance
# 16718            Winning Post 8 2016                     PlayStation Vita
#
#           Año        Género      Compañía    USA  Europa  Japón  Otros
# ...

# %%
video_games_sales_cleaned['Año'] = video_games_sales_cleaned['Año'].astype(int)
video_games_sales_cleaned
# Out:
#                               Nombre                           Plataforma  \
# 0                         Wii Sports                         Nintendo Wii
# 1                  Super Mario Bros.  NES (Nintendo Entertainment System)
# 2                     Mario Kart Wii                         Nintendo Wii
# 3                  Wii Sports Resort                         Nintendo Wii
# 4           Pokemon Red/Pokemon Blue                    Nintendo Game Boy
# ...                              ...                                  ...
# 16714  Samurai Warriors: Sanada Maru                         PlayStation3
# 16715               LMA Manager 2007                              Xbox360
# 16716        Haitaka no Psychedelica                     PlayStation Vita
# 16717               Spirits & Spells                     Game Boy Advance
# 16718            Winning Post 8 2016                     PlayStation Vita
#
#         Año        Género      Compañía    USA  Europa  Japón  Otros
# ...

# %%
video_games_sales_cleaned.to_csv('video_games_ok.csv', index=False)

# %%
video_games_sales_cleaned.iloc[6640]
# Out:
# Nombre        Sid Meier's Civilization VI
# Plataforma                             PC
# Año                                  2016
# Género                           Strategy
# Compañía             Take-Two Interactive
# USA                                  0.09
# Europa                               0.13
# Japón                                 0.0
# Otros                                0.02
# Name: 6754, dtype: object

# %%
from sqlalchemy import create_engine

# %%
with open ('pw.txt') as file:
    password = file.read()

# %%
str_conn = f'mysql+pymysql://root:{password}@localhost:3306/video_games'
cursor = create_engine(str_conn)

# %%
video_games_sales_cleaned.to_sql(name='video_games_sales',       # nombre de la tabla
            con=cursor,           # conexion al servidor
            if_exists='replace',  # replace sobreescribe la tabla
            index=True)
